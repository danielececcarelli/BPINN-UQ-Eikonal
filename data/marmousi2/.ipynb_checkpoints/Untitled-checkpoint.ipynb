# %%
import numpy as np
import matplotlib.pylab as plt

x = np.load("x.npy")
y = np.load("y.npy")
v = np.load("v.npy")
at = np.load("at.npy")

# %%
plt.subplot(1,2,1)
plt.scatter(x, y, c=v, label = 'v', cmap = 'coolwarm', vmin = min(v), vmax = max(v))
plt.colorbar()
plt.xlim([0,30])
plt.ylim([0,6])
# Out:
# (0.0, 6.0)
